# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthi164/LLM/blob/main/LLM1b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob
from textblob import TextBlob

def analyze_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

# Example usage:
sentence1 = "I love this product, it's amazing!"
sentence2 = "This is a terrible experience, very disappointing."
sentence3 = "The weather is okay today."

print(f"'{sentence1}' is: {analyze_sentiment(sentence1)}")
print(f"'{sentence2}' is: {analyze_sentiment(sentence2)}")
print(f"'{sentence3}' is: {analyze_sentiment(sentence3)}")
# Out:
# 'I love this product, it's amazing!' is: Positive
# 'This is a terrible experience, very disappointing.' is: Negative
# 'The weather is okay today.' is: Positive
